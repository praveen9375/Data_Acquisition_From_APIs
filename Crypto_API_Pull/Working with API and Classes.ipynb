# %%
import requests
from requests import Session
import csv

token = "token"

class CMC:
    #https://coinmarketcap.com/api/documentation/v1/
    def __init__(self, token):
        self.apiurl = 'https://pro-api.coinmarketcap.com'
        self.headers = {'Accepts': 'application/json', 'X-CMC_PRO_API_KEY': token,}
        self.session = Session()
        self.session.headers.update(self.headers)
    
    def getAllCoins(self):
        url = self.apiurl + '/v1/cryptocurrency/map'
        r = self.session.get(url)
        data = r.json()['data']
        return data
        
    def getPrice(self, symbol):
        url = self.apiurl + '/v1/cryptocurrency/quotes/latest'
        parameters = {'symbol': symbol}
        r = self.session.get(url, params=parameters)
        data = r.json()['data']
        return data
    
    def saveDataToCSV(self, data):
        keys = data[0].keys()
        filename = 'coins_data.csv'
        with open(filename, 'w', encoding='utf-8', newline='') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=keys)
            writer.writeheader()
            writer.writerows(data)
        print(f"Data saved to {filename}")
    
    
cmc = CMC(token,)

# %%
cmc = CMC(token)
coins_data = cmc.getAllCoins()
cmc.saveDataToCSV(coins_data)
# Out:
# Data saved to coins_data.csv

# %%
import requests
import csv
from requests import Session

token = "token"

class CMC:
    # https://coinmarketcap.com/api/documentation/v1/
    def __init__(self, token):
        self.apiurl = 'https://pro-api.coinmarketcap.com'
        self.headers = {'Accepts': 'application/json', 'X-CMC_PRO_API_KEY': token}
        self.session = Session()
        self.session.headers.update(self.headers)

    def getAllCoins(self, limit=1000):
        url = self.apiurl + '/v1/cryptocurrency/map'
        parameters = {'limit': limit)#q:longitude,latitude,city_name}
        r = self.session.get(url, params=parameters)
        response_data = r.json()
        if 'data' in response_data:
            return response_data['data']
        else:
            print('Failed to retrieve coins. Error:', response_data)
            return []
        
    def splitData(self, data):
        half_length = len(data) // 2
        return data[:half_length], data[half_length:]

    def saveDataToCSV(self, data, filename):
        keys = data[0].keys()
        with open(filename, 'w', encoding='utf-8', newline='') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=keys)
            writer.writeheader()
            writer.writerows(data)
        print(f"Data saved to {filename}")

cmc = CMC(token)
coins_data = cmc.getAllCoins(limit=1000)

half1, half2 = cmc.splitData(coins_data)

cmc.saveDataToCSV(half1, 'coins_data_1.csv')
cmc.saveDataToCSV(half2, 'coins_data_2.csv')
# Out:
# Data saved to coins_data_1.csv
# Data saved to coins_data_2.csv

# %%
import requests
import csv
from requests import Session

token = "token"

class CMC:
    # https://coinmarketcap.com/api/documentation/v1/
    def __init__(self, token):
        self.apiurl = 'https://pro-api.coinmarketcap.com'
        self.headers = {'Accepts': 'application/json', 'X-CMC_PRO_API_KEY': token}
        self.session = Session()
        self.session.headers.update(self.headers)

    def getAllCoins(self, limit=500):
        url = self.apiurl + '/v1/cryptocurrency/map'
        parameters = {'limit': limit}
        r = self.session.get(url, params=parameters)
        response_data = r.json()
        if 'data' in response_data:
            return response_data['data']
        else:
            print('Failed to retrieve coins. Error:', response_data)
            return []

    def saveDataToCSV(self, data):
        selected_columns = [data['id'], data['name'], data['symbol'], data['rank']]
        half_size = len(data) // 2
        first_half_data = data[:half_size]
        second_half_data = data[half_size:]

        # Save first half of the data to CSV
        first_half_filename = 'coins_data_1.csv'
        with open(first_half_filename, 'w', encoding='utf-8', newline='') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=selected_columns)
            writer.writeheader()
            writer.writerows(first_half_data)
        print(f"First half of data saved to {first_half_filename}")

        # Save second half of the data to CSV
        second_half_filename = 'coins_data_2.csv'
        with open(second_half_filename, 'w', encoding='utf-8', newline='') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=selected_columns)
            writer.writeheader()
            writer.writerows(second_half_data)
        print(f"Second half of data saved to {second_half_filename}")
cmc = CMC(token)
coins_data = cmc.getAllCoins(limit=500)
print(coins_data)
#cmc.saveDataToCSV(coins_data)
# Out:
# [{'id': 1, 'rank': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'is_active': 1, 'first_historical_data': '2010-07-13T00:00:00.000Z', 'last_historical_data': '2023-06-07T04:39:00.000Z', 'platform': None}, {'id': 2, 'rank': 12, 'name': 'Litecoin', 'symbol': 'LTC', 'slug': 'litecoin', 'is_active': 1, 'first_historical_data': '2013-04-28T18:47:22.000Z', 'last_historical_data': '2023-06-07T04:39:00.000Z', 'platform': None}, {'id': 3, 'rank': 570, 'name': 'Namecoin', 'symbol': 'NMC', 'slug': 'namecoin', 'is_active': 1, 'first_historical_data': '2013-04-28T18:47:22.000Z', 'last_historical_data': '2023-06-07T04:39:00.000Z', 'platform': None}, {'id': 4, 'rank': 2026, 'name': 'Terracoin', 'symbol': 'TRC', 'slug': 'terracoin', 'is_active': 1, 'first_historical_data': '2013-04-28T18:47:22.000Z', 'last_historical_data': '2023-06-07T04:39:00.000Z', 'platform': None}, {'id': 5, 'rank': 770, 'name': 'Peercoin', 'symbol': 'PPC', 'slug': 'peercoin', 'is_active': 1, 'first_historical_data'
# ...
