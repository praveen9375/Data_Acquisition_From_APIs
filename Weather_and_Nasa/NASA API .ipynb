# %%
import requests

# %%
base_url = 'https://ssd-api.jpl.nasa.gov/cad.api'
response = requests.get(base_url)

# %%
response.json()
# Out:
# {'signature': {'version': '1.5',
#   'source': 'NASA/JPL SBDB Close Approach Data API'},
#  'count': 29,
#  'fields': ['des',
#   'orbit_id',
#   'jd',
#   'cd',
#   'dist',
#   'dist_min',
#   'dist_max',
#   'v_rel',
#   'v_inf',
#   't_sigma_f',
#   'h'],
#  'data': [['2023 LD',
#    '1',
#    '2460104.544739817',
#    '2023-Jun-09 01:04',
#    '0.00635250143701318',
#    '0.00633705426806886',
#    '0.00636794799383735',
#    '9.10322727717039',
#    '9.05703435043221',
#    '< 00:01',
#    '26.314'],
#   ['2023 JB3',
#    '13',
#    '2460105.360445169',
#    '2023-Jun-09 20:39',
#    '0.0362163376263994',
#    '0.0361880148384531',
#    '0.0362446602808189',
#    '6.94939728103983',
#    '6.93880250289472',
#    '< 00:01',
#    '24.174'],
#   ['2023 LA',
#    '2',
#    '2460107.524301873',
#    '2023-Jun-12 00:35',
#    '0.00440986261519941',
#    '0.0043865287455352',
#    '0.00443319376947457',
#    '10.4467832791508',
#    '10.3887854238819',
#    '00:02',
#    '25.207'],
# ...

# %%
import requests

base_url = "https://ssd-api.jpl.nasa.gov/cad.api"
query_params = {
    "des": "433",
    "date-min": "1900-01-01",
    "date-max": "2100-01-01",
    "dist-max": "0.2",
}

responses = requests.get(base_url, params=query_params)
data = responses.json()

# %%
responses.json()
# Out:
# {'signature': {'version': '1.5',
#   'source': 'NASA/JPL SBDB Close Approach Data API'},
#  'count': 5,
#  'fields': ['des',
#   'orbit_id',
#   'jd',
#   'cd',
#   'dist',
#   'dist_min',
#   'dist_max',
#   'v_rel',
#   'v_inf',
#   't_sigma_f',
#   'h'],
#  'data': [['433',
#    '659',
#    '2426371.671249267',
#    '1931-Jan-30 04:07',
#    '0.174073145828143',
#    '0.174073021249871',
#    '0.174073270408642',
#    '5.92081853410288',
#    '5.91823274159338',
#    '< 00:01',
#    '10.31'],
#   ['433',
#    '659',
#    '2442435.819062972',
#    '1975-Jan-23 07:39',
#    '0.151134190879819',
#    '0.151134141782744',
#    '0.151134239976902',
#    '5.82530768329976',
#    '5.82228046582781',
#    '< 00:01',
#    '10.31'],
#   ['433',
#    '659',
#    '2455957.958753891',
#    '2012-Jan-31 11:01',
#    '0.17867581359062',
#    '0.178675792496712',
#    '0.178675834684529',
#    '5.9451959020589',
#    '5.94268706727029',
#    '< 00:01',
#    '10.31'],
#   ['433',
#    '659',
# ...
